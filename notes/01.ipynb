# %%
2020
# Out:
# 2020

# %%
2000 + 20
# Out:
# 2020

# %%
-1 + 2 - 3 + 4 ** 2 + 5 / 2 + 5 // 2
# Out:
# 18.5

# %%
abs(-2)
# Out:
# 2

# %%
"Go Jensen"
# Out:
# 'Go Jensen'

# %%
1 + 3
# Out:
# 4

# %%
shakes = open
